# %%
# %store -r REGRES
# %store -r df2
# %store -r X_limpo
# %store -r Y

import pandas as pd
import numpy as np
from scipy.stats import norm, probplot
import statsmodels.api as sm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
REGRES.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:     Revenue (Millions)   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.336
# Method:                 Least Squares   F-statistic:                     1.511
# Date:                Thu, 21 Nov 2019   Prob (F-statistic):              0.320
# Time:                        10:35:08   Log-Likelihood:                -2843.9
# No. Observations:                 838   AIC:                             7352.
# Df Residuals:                       6   BIC:                         1.129e+04
# Df Model:                         831
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
df2;

# %%
lista = df2.Actors[0].split(",")

# %%
lista2 = ["Robert Downey Jr.", "Chris Evans", "Mark Ruffalo", "Chris Hemsworth", "Scarlett Johansson", "Jeremy Renner", "Don Cheadle", "Paul Rudd", "Benedict Cumberbatch", "Chadwick Boseman", "Brie Larson", "Tom Holland", "Karen Gillan", "Zoe Saldana", "Evangeline Lilly"]

# %%
lista2
# Out:
# ['Robert Downey Jr.',
#  'Chris Evans',
#  'Mark Ruffalo',
#  'Chris Hemsworth',
#  'Scarlett Johansson',
#  'Jeremy Renner',
#  'Don Cheadle',
#  'Paul Rudd',
#  'Benedict Cumberbatch',
#  'Chadwick Boseman',
#  'Brie Larson',
#  'Tom Holland',
#  'Karen Gillan',
#  'Zoe Saldana',
#  'Evangeline Lilly']

# %%
fatura = 0
for actor in lista2:
    if actor in REGRES.params.index:
        fatura += REGRES.params[actor]
print(fatura)
# Out:
# 775.3441311279939

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_limpo, Y, test_size=0.05, random_state=15)

# %%
def regress(X,Y):
    X_cp = sm.add_constant(X)
    model = sm.OLS(Y,X_cp)
    results = model.fit()
    return results

# %%
regressao2 = regress(X_train, y_train)

# %%
regressao2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:     Revenue (Millions)   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.269
# Method:                 Least Squares   F-statistic:                     1.370
# Date:                Thu, 21 Nov 2019   Prob (F-statistic):              0.399
# Time:                        10:37:16   Log-Likelihood:                -2692.2
# No. Observations:                 796   AIC:                             6966.
# Df Residuals:                       5   BIC:                         1.067e+04
# Df Model:                         790
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
y_test
# Out:
# 495    256.39
# 677      0.01
# 817     18.33
# 142     70.24
# 658     17.11
# 379     39.29
# 738      0.56
# 884      0.03
# 922     64.15
# 210    155.18
# 583     41.10
# 518    258.36
# 281    209.02
# 867      0.64
# 114    380.96
# 166     65.03
# 831     49.00
# 683     31.17
# 753     54.76
# 807      6.85
# 118     71.90
# 352      2.02
# 740     63.03
# 90      60.96
# 936      0.18
# 33     363.02
# 188     35.05
# 460     92.17
# 451      1.82
# 288     17.36
# 548      0.11
# 324     96.92
# 904     58.61
# 353     11.08
# 163     58.40
# 571    127.71
# 348     16.20
# 776      0.78
# 88      54.12
# 277     33.05
# 64      53.08
# 565     34.96
# Name: Revenue (Millions), dtype: float64

# %%
y_train
# Out:
# 520      2.96
# 461     35.79
# 682     14.01
# 234     47.95
# 233    195.00
# 900      0.81
# 742     20.17
# 594    150.32
# 708     47.11
# 68       0.01
# 195    176.64
# 181     25.14
# 618      0.03
# 78     423.03
# 823      0.30
# 101    181.02
# 595     12.13
# 344    336.53
# 562     48.06
# 473    301.96
# 728     77.21
# 389     73.06
# 664      0.28
# 106      1.66
# 961      0.01
# 45     241.06
# 3      270.32
# 414     21.20
# 440    234.90
# 310    255.95
#         ...
# 1      126.46
# 201      8.10
# 16      67.12
# 116      1.33
# 375      2.20
# 177    110.42
# 845     93.75
# 959     22.49
# 20       7.22
# 952     95.33
# 46       3.44
# 223    102.52
# 162    233.91
# 915      0.79
# 357     35.89
# 472    166.11
# 28     113.08
# 880      1.91
# 18      51.69
# 249     13.18
# 731     37.37
# 96       4.68
# 843    104.37
# 226      8.70
# 781     12.28
# 176    208.54
# 436     37.43
# 749     68.56
# 888     25.00
# 521     16.97
# ...

# %%
X_test_c = sm.add_constant(X_test)

# %%
y_pred = regressao2.predict(X_test_c)

# %%
from sklearn.metrics import *

# %%
r2_score(y_pred, y_test)
# Out:
# -0.20867585110589038

# %%
mean_absolute_error(y_pred, y_test)
# Out:
# 99.58424687064496

# %%
explained_variance_score(y_pred, y_test)
# Out:
# -0.16050365621587281
